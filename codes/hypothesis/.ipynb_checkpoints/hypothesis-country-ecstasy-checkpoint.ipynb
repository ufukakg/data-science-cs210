# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
# %matplotlib inline

file = '../../input/drug_data.csv'
drug_data = pd.read_csv(file,'rb', delimiter =';')
#train.describe()

# %%
drug_data.head(8)
#train.shape
# Out:
#    ID       Age    Gender Education   Country Ethnicity    Nscore    Escore  \
# 0   1   0,49788   0,48246  -0,05921   0,96082     0,126   0,31287  -0,57545
# 1   2  -0,07854  -0,48246   1,98437   0,96082  -0,31685  -0,67825   1,93886
# 2   3   0,49788  -0,48246  -0,05921   0,96082  -0,31685  -0,46725   0,80523
# 3   4  -0,95197   0,48246   1,16365   0,96082  -0,31685  -0,14882  -0,80615
# 4   5   0,49788   0,48246   1,98437   0,96082  -0,31685   0,73545   -1,6334
# 5   6   2,59171   0,48246  -1,22751   0,24923  -0,31685  -0,67825  -0,30033
# 6   7   1,09449  -0,48246   1,16365  -0,57009  -0,31685  -0,46725  -1,09207
# 7   8   0,49788  -0,48246   -1,7379   0,96082  -0,31685  -1,32828   1,93886
#
#      Oscore    Ascore ...  Ecstasy Heroin Ketamine Legalh  LSD Meth Mushrooms  \
# 0  -0,58331  -0,91699 ...      CL0    CL0      CL0    CL0  CL0  CL0       CL0
# 1   1,43533   0,76096 ...      CL4    CL0      CL2    CL0  CL2  CL3       CL0
# ...

# %% [markdown]
# # <h3> Data manipulation (Object to numericals)

# %%
def handle_non_numerical_data(df):
    columns = df.columns.values
    
    for column in columns:
        text_digit_vals = {}
        def convert_to_int(val):
            return text_digit_vals[val]
        
        if df[column].dtype != np.int64 and df[column].dtype != np.float64:
            print(column)
            column_contents = df[column].values.tolist()
            unique_elements = set(column_contents)
            x=0
            for unique in unique_elements:
                if unique not in text_digit_vals:
                    print(unique + " : " + str(x))
                    text_digit_vals[unique] = x
                    x+=1        
            df[column] = list(map(convert_to_int, df[column])) 
    
    return df

# %%
for i in range(13,32):
    drug_data[drug_data.columns[i]] = drug_data[drug_data.columns[i]].str.replace('CL','').astype(int)

# %%
for i in range(1,13):
    drug_data[drug_data.columns[i]] = drug_data[drug_data.columns[i]].str.replace(',','.').astype(np.float64)

# %%
def change_age(cls):
    if cls == -0.95197:
        return '18-24'
    elif cls == -0.07854:
        return '25-34'
    elif cls == 0.49788:
        return '35-44'
    elif cls == 1.09449:
        return '45-54'
    elif cls == 1.82213:
        return '55-64'
    elif cls == 2.59171:
        return '65+'
    
def change_gender(cls):
    if cls == 0.48246:
        return "male"
    elif cls == -0.48246:
        return "female"

def change_country(cls):
    if cls == -0.09765:
        return "Australia"
    elif cls == 0.24923:
        return "Canada"
    elif cls == -0.46841:
        return "New Zealand"
    elif cls == -0.28519:
        return "Other"
    elif cls == 0.21128:
        return "Rep.of Ireland"
    elif cls == 0.96082:
        return "UK"
    elif cls == -0.57009:
        return "USA"

# %%
# drug_data['Age'] = drug_data['Age'].str.replace(',','.').astype(np.float64)
drug_data['Age'] = drug_data['Age'].apply(change_age)

# %%
# drug_data['Gender'] = drug_data['Gender'].str.replace(',','.').astype(np.float64)
drug_data['Gender'] = drug_data['Gender'].apply(change_gender)

# %%
drug_data['Country'] = drug_data['Country'].apply(change_country)

# %%
drug_data.head(8)
# Out:
#    ID    Age  Gender  Education Country  Ethnicity   Nscore   Escore   Oscore  \
# 0   1  35-44    male   -0.05921      UK    0.12600  0.31287 -0.57545 -0.58331
# 1   2  25-34  female    1.98437      UK   -0.31685 -0.67825  1.93886  1.43533
# 2   3  35-44  female   -0.05921      UK   -0.31685 -0.46725  0.80523 -0.84732
# 3   4  18-24    male    1.16365      UK   -0.31685 -0.14882 -0.80615 -0.01928
# 4   5  35-44    male    1.98437      UK   -0.31685  0.73545 -1.63340 -0.45174
# 5   6    65+    male   -1.22751  Canada   -0.31685 -0.67825 -0.30033 -1.55521
# 6   7  45-54  female    1.16365     USA   -0.31685 -0.46725 -1.09207 -0.45174
# 7   8  35-44  female   -1.73790      UK   -0.31685 -1.32828  1.93886 -0.84732
#
#     Ascore ...   Ecstasy  Heroin  Ketamine  Legalh  LSD  Meth  Mushrooms  \
# 0 -0.91699 ...         0       0         0       0    0     0          0
# 1  0.76096 ...         4       0         2       0    2     3          0
# ...

# %%
# drug_data = handle_non_numerical_data(drug_data)

# %%
drug_data.head(8)
# Out:
#    ID    Age  Gender  Education Country  Ethnicity   Nscore   Escore   Oscore  \
# 0   1  35-44    male   -0.05921      UK    0.12600  0.31287 -0.57545 -0.58331
# 1   2  25-34  female    1.98437      UK   -0.31685 -0.67825  1.93886  1.43533
# 2   3  35-44  female   -0.05921      UK   -0.31685 -0.46725  0.80523 -0.84732
# 3   4  18-24    male    1.16365      UK   -0.31685 -0.14882 -0.80615 -0.01928
# 4   5  35-44    male    1.98437      UK   -0.31685  0.73545 -1.63340 -0.45174
# 5   6    65+    male   -1.22751  Canada   -0.31685 -0.67825 -0.30033 -1.55521
# 6   7  45-54  female    1.16365     USA   -0.31685 -0.46725 -1.09207 -0.45174
# 7   8  35-44  female   -1.73790      UK   -0.31685 -1.32828  1.93886 -0.84732
#
#     Ascore ...   Ecstasy  Heroin  Ketamine  Legalh  LSD  Meth  Mushrooms  \
# 0 -0.91699 ...         0       0         0       0    0     0          0
# 1  0.76096 ...         4       0         2       0    2     3          0
# ...

# %%
drug_data.dtypes
# Out:
# ID             int64
# Age           object
# Gender        object
# Education    float64
# Country       object
# Ethnicity    float64
# Nscore       float64
# Escore       float64
# Oscore       float64
# Ascore       float64
# Cscore       float64
# Impulsive    float64
# SS           float64
# Alcohol        int64
# Amphet         int64
# Amyl           int64
# Benzos         int64
# Caffeine       int64
# Cannabis       int64
# Chocolate      int64
# Cocaine        int64
# Crack          int64
# Ecstasy        int64
# Heroin         int64
# Ketamine       int64
# Legalh         int64
# LSD            int64
# Meth           int64
# Mushrooms      int64
# Nicotine       int64
# Semer          int64
# VSA            int64
# dtype: object

# %%
samples = drug_data[['Country','Ecstasy']]

# %%
ecs_freq = pd.value_counts(samples['Ecstasy'])
ecs_freq/len(samples)
# Out:
# 0    0.541645
# 3    0.146950
# 2    0.124138
# 4    0.082759
# 1    0.059947
# 5    0.033422
# 6    0.011141
# Name: Ecstasy, dtype: float64

# %%
ecs_table = pd.crosstab(index=samples['Ecstasy'], columns=["count"])
ecs_ratio = ecs_table/len(drug_data)
ecs_ratio
# Out:
# col_0       count
# Ecstasy
# 0        0.541645
# 1        0.059947
# 2        0.124138
# 3        0.146950
# 4        0.082759
# 5        0.033422
# 6        0.011141

# %%
country_0 = samples[drug_data["Country"]=='USA']
ecs_0 = pd.crosstab(index=country_0['Ecstasy'], columns=["count"])
ecs_0_ratio = ecs_0/len(country_0)
ecs_0_ratio
# Out:
# col_0       count
# Ecstasy
# 0        0.335727
# 1        0.057451
# 2        0.166966
# 3        0.238779
# 4        0.122083
# 5        0.061041
# 6        0.017953

# %%
observed = ecs_0
general_ratios = ecs_ratio
expected = general_ratios * len(country_0)
chi_squared_stat = (((observed-expected)**2)/expected).sum()
print(chi_squared_stat)
# Out:
# col_0
# count    109.297018
# dtype: float64

# %%
critical_value = crit = stats.chi2.ppf(q = 0.95, # Find the critical value for 95% confidence*
                      df = 6)   # Df = number of variable categories - 1

print("Critical value")
print(crit)

p_value = 1 - stats.chi2.cdf(x=chi_squared_stat,  # Find the p-value
                             df=6)
print("P value: ", p_value)
print(stats.chisquare(f_obs= observed, f_exp= expected))
chi_stats = [chi_squared_stat, p_value, 6, ecs_ratio]
chi_stats
# Out:
# Critical value
# 12.5915872437
# P value:  [ 0.]
# Power_divergenceResult(statistic=array([ 109.29701799]), pvalue=array([  2.86069389e-21]))
# [col_0
#  count    109.297018
#  dtype: float64, array([ 0.]), 6, col_0       count
#  Ecstasy
#  0        0.541645
#  1        0.059947
#  2        0.124138
#  3        0.146950
#  4        0.082759
#  5        0.033422
#  6        0.011141]

# %%
x = np.linspace(0, 25, 1000)  # set range for x-axis
plt.plot(x, stats.chi2.pdf(x, chi_stats[0]))  # plot chi2 distribution with given degrees of freedom

plt.axvline(x=critical_value, ymin=0.05,ymax=0.05, c='r')
plt.axvline(x=chi_stats[0], ymin=0.05,ymax=0.1, c='r')

plt.annotate('Current Value = {0:.2f}'.format(chi_stats[0]), xy=(chi_stats[0], 0.02), xytext=(chi_stats[0], 0.01))

plt.annotate('Critical Value = {0:.2f}'.format(critical_value), xy=(critical_value, 0.02), xytext=(critical_value, 0.04), 
        arrowprops=dict(facecolor='black', shrink=0.5), verticalalignment='top' )

plt.fill_between(x, stats.chi2.pdf(x, chi_stats[2]), where= x > critical_value, facecolor='red', interpolate=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-8c3906307db2> in <module>()
#       3
#       4 plt.axvline(x=critical_value, ymin=0.05,ymax=0.05, c='r')
# ----> 5 plt.axvline(x=chi_stats[0], ymin=0.05,ymax=0.1, c='r')
#       6
#       7 plt.annotate('Current Value = {0:.2f}'.format(chi_stats[0]), xy=(chi_stats[0], 0.02), xytext=(chi_stats[0], 0.01))
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in axvline(x, ymin, ymax, hold, **kwargs)
#    2583                       mplDeprecation)
#    2584     try:
# -> 2585         ret = ax.axvline(x=x, ymin=ymin, ymax=ymax, **kwargs)
#    2586     finally:
#    2587         ax._hold = washold
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in axvline(self, x, ymin, ymax, **kwargs)
#     793         self._process_unit_info(xdata=x, kwargs=kwargs)
# ...

# %%
x = np.linspace(0, 25, 1000)
plt.plot(x, stats.chi2.pdf(x, chi_stats[2]))
plt.axvline(x=critical_value, ymin=0.05,ymax=0.05, c='r')
plt.annotate('Critical Value = {0:.2f}'.format(critical_value), xy=(critical_value, 0.02), xytext=(critical_value, 0.04), 
            arrowprops=dict(facecolor='black', shrink=0.5), verticalalignment='top' )
plt.fill_between(x, stats.chi2.pdf(x, chi_stats[2]), where= x > critical_value, facecolor='red', interpolate=True)

# %%
   # Array of expected counts
# Out:
# Power_divergenceResult(statistic=array([ 109.29701799]), pvalue=array([  2.86069389e-21]))
