# %%
import pandas as pd
import numpy as np 

import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
# %matplotlib inline

file = '../input/drug_data.csv'
drug_data = pd.read_csv(file,'rb', delimiter =';')
#train.describe()

# %%
drug_data.head(8)
#train.shape
# Out:
#    ID       Age    Gender Education   Country Ethnicity    Nscore    Escore  \
# 0   1   0,49788   0,48246  -0,05921   0,96082     0,126   0,31287  -0,57545
# 1   2  -0,07854  -0,48246   1,98437   0,96082  -0,31685  -0,67825   1,93886
# 2   3   0,49788  -0,48246  -0,05921   0,96082  -0,31685  -0,46725   0,80523
# 3   4  -0,95197   0,48246   1,16365   0,96082  -0,31685  -0,14882  -0,80615
# 4   5   0,49788   0,48246   1,98437   0,96082  -0,31685   0,73545   -1,6334
# 5   6   2,59171   0,48246  -1,22751   0,24923  -0,31685  -0,67825  -0,30033
# 6   7   1,09449  -0,48246   1,16365  -0,57009  -0,31685  -0,46725  -1,09207
# 7   8   0,49788  -0,48246   -1,7379   0,96082  -0,31685  -1,32828   1,93886
#
#      Oscore    Ascore ...  Ecstasy Heroin Ketamine Legalh  LSD Meth Mushrooms  \
# 0  -0,58331  -0,91699 ...      CL0    CL0      CL0    CL0  CL0  CL0       CL0
# 1   1,43533   0,76096 ...      CL4    CL0      CL2    CL0  CL2  CL3       CL0
# ...

# %% [markdown]
# # <h3> Data manipulation (Object to numericals)

# %%
def handle_non_numerical_data(df):
    columns = df.columns.values
    
    for column in columns:
        text_digit_vals = {}
        def convert_to_int(val):
            return text_digit_vals[val]
        
        if df[column].dtype != np.int64 and df[column].dtype != np.float64:
            print(column)
            column_contents = df[column].values.tolist()
            unique_elements = set(column_contents)
            x=0
            for unique in unique_elements:
                if unique not in text_digit_vals:
                    print(unique + " : " + str(x))
                    text_digit_vals[unique] = x
                    x+=1        
            df[column] = list(map(convert_to_int, df[column])) 
    
    return df

# %%
for i in range(13,32):
    drug_data[drug_data.columns[i]] = drug_data[drug_data.columns[i]].str.replace('CL','').astype(int)

# %%
for i in range(6,13):
    drug_data[drug_data.columns[i]] = drug_data[drug_data.columns[i]].str.replace(',','.').astype(np.float64)

# %%
def change_age(cls):
    if cls == -0.95197:
        return '18-24'
    elif cls == -0.07854:
        return '25-34'
    elif cls == 0.49788:
        return '35-44'
    elif cls == 1.09449:
        return '45-54'
    elif cls == 1.82213:
        return '55-64'
    elif cls == 2.59171:
        return '65+'
    
def change_gender(cls):
    if cls == 0.48246:
        return "male"
    elif cls == -0.48246:
        return "female"

# %%
drug_data['Age'] = drug_data['Age'].str.replace(',','.').astype(np.float64)
drug_data['Age'] = drug_data['Age'].apply(change_age)

# %%
drug_data['Gender'] = drug_data['Gender'].str.replace(',','.').astype(np.float64)
drug_data['Gender'] = drug_data['Gender'].apply(change_gender)

# %%
drug_data.head(8)
# Out:
#    ID    Age  Gender Education   Country Ethnicity   Nscore   Escore   Oscore  \
# 0   1  35-44    male  -0,05921   0,96082     0,126  0.31287 -0.57545 -0.58331
# 1   2  25-34  female   1,98437   0,96082  -0,31685 -0.67825  1.93886  1.43533
# 2   3  35-44  female  -0,05921   0,96082  -0,31685 -0.46725  0.80523 -0.84732
# 3   4  18-24    male   1,16365   0,96082  -0,31685 -0.14882 -0.80615 -0.01928
# 4   5  35-44    male   1,98437   0,96082  -0,31685  0.73545 -1.63340 -0.45174
# 5   6    65+    male  -1,22751   0,24923  -0,31685 -0.67825 -0.30033 -1.55521
# 6   7  45-54  female   1,16365  -0,57009  -0,31685 -0.46725 -1.09207 -0.45174
# 7   8  35-44  female   -1,7379   0,96082  -0,31685 -1.32828  1.93886 -0.84732
#
#     Ascore ...   Ecstasy  Heroin  Ketamine  Legalh  LSD  Meth  Mushrooms  \
# 0 -0.91699 ...         0       0         0       0    0     0          0
# 1  0.76096 ...         4       0         2       0    2     3          0
# ...

# %%
# drug_data = handle_non_numerical_data(drug_data)

# %%
drug_data.head(8)
# Out:
#    ID    Age  Gender Education   Country Ethnicity   Nscore   Escore   Oscore  \
# 0   1  35-44    male  -0,05921   0,96082     0,126  0.31287 -0.57545 -0.58331
# 1   2  25-34  female   1,98437   0,96082  -0,31685 -0.67825  1.93886  1.43533
# 2   3  35-44  female  -0,05921   0,96082  -0,31685 -0.46725  0.80523 -0.84732
# 3   4  18-24    male   1,16365   0,96082  -0,31685 -0.14882 -0.80615 -0.01928
# 4   5  35-44    male   1,98437   0,96082  -0,31685  0.73545 -1.63340 -0.45174
# 5   6    65+    male  -1,22751   0,24923  -0,31685 -0.67825 -0.30033 -1.55521
# 6   7  45-54  female   1,16365  -0,57009  -0,31685 -0.46725 -1.09207 -0.45174
# 7   8  35-44  female   -1,7379   0,96082  -0,31685 -1.32828  1.93886 -0.84732
#
#     Ascore ...   Ecstasy  Heroin  Ketamine  Legalh  LSD  Meth  Mushrooms  \
# 0 -0.91699 ...         0       0         0       0    0     0          0
# 1  0.76096 ...         4       0         2       0    2     3          0
# ...

# %%
drug_data.dtypes
# Out:
# ID             int64
# Age           object
# Gender        object
# Education     object
# Country       object
# Ethnicity     object
# Nscore       float64
# Escore       float64
# Oscore       float64
# Ascore       float64
# Cscore       float64
# Impulsive    float64
# SS           float64
# Alcohol        int64
# Amphet         int64
# Amyl           int64
# Benzos         int64
# Caffeine       int64
# Cannabis       int64
# Chocolate      int64
# Cocaine        int64
# Crack          int64
# Ecstasy        int64
# Heroin         int64
# Ketamine       int64
# Legalh         int64
# LSD            int64
# Meth           int64
# Mushrooms      int64
# Nicotine       int64
# Semer          int64
# VSA            int64
# dtype: object

# %%
sample_columns = drug_data[['Age','Nicotine']]

# %%
age_freq = pd.value_counts(sample_columns['Age'])
age_freq/len(sample_columns)
# Out:
# 18-24    0.341114
# 25-34    0.255172
# 35-44    0.188859
# 45-54    0.155968
# 55-64    0.049337
# 65+      0.009549
# Name: Age, dtype: float64

# %%
age_table = pd.crosstab(index=sample_columns['Age'], columns=["count"])
age_ratio = nicotine_table/len(drug_data)
age_ratio
# Out:
# col_0     count
# Age
# 18-24  0.341114
# 25-34  0.255172
# 35-44  0.188859
# 45-54  0.155968
# 55-64  0.049337
# 65+    0.009549

# %%
yest_used = sample_columns[drug_data["Nicotine"]==6]
age_0 = pd.crosstab(index=yest_used['Age'], columns=["count"])
age_0_ratio = age_0/len(yest_used)
age_0_ratio
# Out:
# col_0     count
# Age
# 18-24  0.398361
# 25-34  0.249180
# 35-44  0.178689
# 45-54  0.122951
# 55-64  0.042623
# 65+    0.008197

# %%
observed = age_0
general_ratios = age_ratio
expected = general_ratios * len(yest_used)
chi_squared_stat = (((observed-expected)**2)/expected).sum()
print(chi_squared_stat)
# Out:
# col_0
# count    11.218163
# dtype: float64

# %%
crit = stats.chi2.ppf(q = 0.95, # Find the critical value for 95% confidence*
                      df = 5)   # Df = number of variable categories - 1

print("Critical value")
print(crit)

p_value = 1 - stats.chi2.cdf(x=chi_squared_stat,  # Find the p-value
                             df=5)
print("P value")
print(p_value)
# Out:
# Critical value
# 11.0704976935
# P value
# [ 0.04722199]

# %%
stats.chisquare(f_obs= observed,   # Array of observed counts
                f_exp= expected)   # Array of expected counts
# Out:
# Power_divergenceResult(statistic=array([ 11.21816257]), pvalue=array([ 0.04722199]))

# %%
relation = sample_columns.groupby(['Age'])['Nicotine'].value_counts()
relation
# Out:
# Age    Nicotine
# 18-24  6           243
#        0           107
#        3            91
#        5            84
#        4            68
#        2            48
#        1             2
# 25-34  6           152
#        0           109
#        2            68
#        3            52
#        5            45
#        1            32
#        4            23
# 35-44  6           109
#        0            78
#        1            62
#        2            51
#        3            26
#        5            21
#        4             9
# 45-54  0           102
#        6            75
#        1            58
#        2            33
#        3            14
#        4             6
#        5             6
# 55-64  1            33
#        6            26
#        0            25
#        2             4
#        3             2
#        4             2
#        5             1
# 65+    0             7
#        1             6
#        6             5
# Name: Nicotine, dtype: int64

# %%
pd.Series(relation).sum()
# Out:
# 1885

# %%
addicted = []
non_addict = []
for i in range(0, 6):
    if relation[i][1] == 6:
        print(relation[i][0])
# Out:
# 7

# %%
relation = relation.reset_index()
relation
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/multi.py in get_value(self, series, key)
#     826             try:
# --> 827                 return libindex.get_value_at(s, k)
#     828             except IndexError:
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/src/util.pxd in util.get_value_at()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-8c8e189768a1> in <module>()
# ----> 1 relation = relation['Age'].reset_index()
#       2 relation
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
# ...

# %%
"""
corr = train.corr()
corr.sort_values(['Age'], ascending = False, inplace = True)
print(corr.Age)
"""
# Out:
# "\ncorr = train.corr()\ncorr.sort_values(['Age'], ascending = False, inplace = True)\nprint(corr.Age)\n"

# %%
relation.pivot('Age').head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-6c64ec97f6d2> in <module>()
# ----> 1 relation.pivot('Age').head()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'pivot'

# %%
relation.pivot('Cannabis','Chocolate')['Age'].head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-e84455f8110a> in <module>()
# ----> 1 relation.pivot('Cannabis','Chocolate')['Age'].head()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'pivot'

# %%
plt.figure(figsize=(9,9))
pivot_table = relation.pivot('Cannabis','Chocolate','Age')
plt.xlabel('Chocolate', size=15)
plt.ylabel('Cannabis', size=15)
plt.title("Choco&Cannabis relation with AGE", size=16)
sns.heatmap(pivot_table, annot=True, fmt=".1f", lineWidth=.5, square=True, cmap='Blues_r')

# f, ax = plt.subplots(figsize=(20, 18))
# sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-7de8480d2d05> in <module>()
#       1 plt.figure(figsize=(9,9))
# ----> 2 pivot_table = relation.pivot('Cannabis','Chocolate','Age')
#       3 plt.xlabel('Chocolate', size=15)
#       4 plt.ylabel('Cannabis', size=15)
#       5 plt.title("Choco&Cannabis relation with AGE", size=16)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'pivot'
